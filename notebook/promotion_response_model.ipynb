# %% [markdown]
# # Promotion Response Prediction
#
# ## Executive Summary
#
# **Business goal:** Rank customers by their likelihood of responding to a retail promotion so the marketing team can focus budget on those most likely to engage.
#
# **What we built:** A LightGBM classification model trained on 20,000 labelled promotion events, using 71 features engineered from historical transaction behaviour (recency, frequency, brand affinity, store context, price sensitivity).
#
# **Key results (see analysis below):**
# - Validation AUC: **0.713** vs 0.50 random baseline
# - 5-fold cross-validated AUC confirms stability: **0.71 ± 0.01**
# - Targeting the **top 20% of predicted scores** captures approximately **2× more responders** than random outreach
# - Recommended decision threshold: **~0.25** (maximises F1 given the 80/20 class imbalance)
#
# **Bottom line:** Deploying this model for campaign targeting can meaningfully reduce wasted spend while maintaining response volume.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# ── Shared colour tokens ─────────────────────────────────────────────────────
C1   = "#EF9F27"   # primary orange
C2   = "#B4B2A9"   # warm gray
DARK = "#333333"   # text / annotations

# ── Global matplotlib style ──────────────────────────────────────────────────
plt.rcParams.update({
    "font.family"       : "sans-serif",
    "font.sans-serif"   : ["Helvetica Neue", "Arial", "DejaVu Sans"],
    "font.size"         : 11,
    "axes.titlesize"    : 13,
    "axes.titleweight"  : "bold",
    "axes.titlepad"     : 10,
    "axes.labelsize"    : 11,
    "axes.labelpad"     : 6,
    "axes.labelcolor"   : DARK,
    "xtick.labelsize"   : 10,
    "ytick.labelsize"   : 10,
    "xtick.color"       : "#666666",
    "ytick.color"       : "#666666",
    "xtick.major.size"  : 4,
    "ytick.major.size"  : 4,
    "legend.fontsize"   : 10,
    "legend.frameon"    : False,
    "axes.spines.top"   : False,
    "axes.spines.right" : False,
    "axes.edgecolor"    : "#CCCCCC",
    "axes.linewidth"    : 0.8,
    "axes.grid"         : True,
    "axes.axisbelow"    : True,
    "grid.color"        : "#EBEBEB",
    "grid.linewidth"    : 0.6,
    "figure.facecolor"  : "white",
    "axes.facecolor"    : "white",
    "savefig.dpi"       : 180,
    "savefig.facecolor" : "white",
    "savefig.bbox"      : "tight",
})

# %% [markdown]
# # Load Data
#
# Upload the files to your Google Drive and mount it in the Colab notebook using the code below.
#
# Files: `promos.parquet`, `test_history.parquet`, `train_history.parquet`, and `transactions.parquet`.

# %%
# This will ask you to give Colab permission to access your Google Drive
# and enter an authorization code.
# See: https://colab.research.google.com/notebooks/io.ipynb#scrollTo=u22w3BFiOveA
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Set this to the folder in your Google Drive that contains the data files.
# path = '/content/drive/MyDrive/your_folder_name'

path = '/content/drive/MyDrive/RSM8421_Assign4'

# %%
promos = pd.read_parquet(path + '/promos.parquet')
promos.head()
# Out:
#     promo  category  promoqty  manufacturer  promoval       brand
# 0  209524  51006740         1    1593002228      1.00   189092190
# 1  176321  42760698         1    1957688344      0.75  1386413202
# 2   17125  56844954         1     629075831      1.50  1429623935
# 3  177412  56844954         1     629075831      1.50  1429623935
# 4   69839  56844954         1     629075831      1.50  1429623935

# %%
train_history = pd.read_parquet(path + '/train_history.parquet')
train_history.head()
# Out:
#              id    store   promo  region  promodate  active
# 0  115562959531   860548  176321  243820 2013-03-25     0.0
# 1  175261390705   625933   37568  191747 2013-03-15     0.0
# 2  273751574633   527828  209524  165933 2013-03-23     1.0
# 3  166923268906  1056730  214816    5506 2013-03-20     0.0
# 4  135410903443   241369  176321  278897 2013-03-25     0.0

# %%
test_history = pd.read_parquet(path + '/test_history.parquet')
test_history.head()
# Out:
#              id   store   promo  region  promodate  active
# 0  250462324156  457755   96852  191747 2013-04-22     NaN
# 1   61214568335  740794   54956  203586 2013-04-23     NaN
# 2  274776763999  394092   95011   42773 2013-04-02     NaN
# 3   91546215019  876095  108237  323706 2013-04-24     NaN
# 4  220718580189  625933  222088  191747 2013-04-18     NaN

# %%
transactions = pd.read_parquet(path + '/transactions.parquet')
transactions.head()
# Out:
#             id  store  market_group  category  manufacturer       brand  \
# 0  31924309471  96431        360548  10881580     707582354   109487351
# 1  31924309471  96431         80472  75959720    2052533430   254982935
# 2  31924309471  96431        194893  80209099    1640770606  1252530761
# 3  31924309471  96431         27828  10942974     946555356  2133681340
# 4  31924309471  96431        135933  64737859     700393013   221618334
#
#         date  productsize measure  qty    amt
# 0 2012-03-06        28.00      OZ    1   2.69
# 1 2012-03-06        12.00      OZ    2   8.48
# 2 2012-03-06         6.00      OZ    1   1.69
# 3 2012-03-06         0.75      LT    1  11.41
# 4 2012-03-06        33.84      OZ    1   3.19

# %%
# ── Dataset shapes ───────────────────────────────────────────────────────────
print("=== Dataset shapes ===")
for name, df in [("train_history", train_history), ("test_history", test_history),
                 ("transactions", transactions), ("promos", promos)]:
    print(f"  {name:<20} {df.shape[0]:>10,} rows  x  {df.shape[1]} cols")

# ── Class imbalance ───────────────────────────────────────────────────────────
print("\n=== Target variable distribution ===")
vc    = train_history["active"].value_counts().sort_index()
total = len(train_history)
for label, count in vc.items():
    tag = "Responded (1)" if label == 1.0 else "No response (0)"
    bar = "█" * int(count / 400)
    print(f"  {tag}: {count:>6,}  ({count/total:.1%})  {bar}")
print(f"  Class imbalance ratio: {vc.get(0.0, 0) / vc.get(1.0, 1):.1f}:1 (negative:positive)")

# ── Missing values ────────────────────────────────────────────────────────────
print("\n=== Missing values ===")
for name, df in [("train_history", train_history), ("transactions", transactions), ("promos", promos)]:
    missing = df.isnull().sum()
    missing = missing[missing > 0]
    if len(missing) == 0:
        print(f"  {name}: no missing values")
    else:
        print(f"  {name}:")
        for col, n in missing.items():
            print(f"    {col}: {n:,} ({n/len(df):.1%})")

# ── Transaction date range ────────────────────────────────────────────────────
transactions["date"] = pd.to_datetime(transactions["date"])
print(f"\n=== Transaction history window ===")
print(f"  {transactions['date'].min().date()}  →  {transactions['date'].max().date()}")
print(f"  Unique customers in transactions: {transactions['id'].nunique():,}")
print(f"  Unique customers in training set: {train_history['id'].nunique():,}")

# ── Class imbalance bar chart ─────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(5, 3.8))
labels = ["No response (0)", "Responded (1)"]
counts = [int(vc.get(0.0, 0)), int(vc.get(1.0, 0))]
bars   = ax.bar(labels, counts, color=[C2, C1], width=0.5, zorder=3)
for bar, count in zip(bars, counts):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 200,
            f"{count:,}\n({count/total:.0%})", ha="center", va="bottom",
            fontsize=9.5, color=DARK)
ax.set_ylabel("Number of promotions")
ax.set_title("Class Distribution — Training Set (20,000 events)")
ax.set_ylim(0, max(counts) * 1.2)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{int(x):,}"))
plt.tight_layout(pad=1.5)
plt.savefig("class_distribution.png")
plt.show()
# Out:
# === Dataset shapes ===
#   train_history            20,000 rows  x  6 cols
#   test_history             10,000 rows  x  6 cols
#   transactions         34,184,139 rows  x  11 cols
#   promos                       24 rows  x  6 cols
#
# === Target variable distribution ===
#   No response (0): 15,950  (79.8%)  ███████████████████████████████████████
#   Responded (1):  4,050  (20.2%)  ██████████
#   Class imbalance ratio: 3.9:1 (negative:positive)
#
# === Missing values ===
#   train_history: no missing values
#   transactions:
#     measure: 971,343 (2.8%)
#   promos: no missing values
#
# === Transaction history window ===
#   2012-03-02  →  2013-02-28
#   Unique customers in transactions: 29,988
#   Unique customers in training set: 20,000

# %% [markdown]
# # Extract Features

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import roc_auc_score

# %%
# Merge promotion info
train_history = train_history.merge(promos, on="promo", how="left")
test_history = test_history.merge(promos, on="promo", how="left")

# %%
import pandas as pd
import numpy as np
import gc

def feature_engineering(df, transactions, train_df, promos=None):
    """
    Optimized memory-efficient, past-only feature engineering for promotion response classification.
    Focuses on high-impact features with minimal runtime.

    Args:
        df: train_history or test_history dataframe
        transactions: transaction history dataframe
        train_df: training set for computing target encodings
        promos: promos dataframe with promotion details (optional but recommended)
    """
    df = df.copy()
    transactions = transactions.copy()  # Prevent modifying original
    smooth_k = 5
    sparse_thresh = 10
    recent_window_days = 30

    print(f"Processing {len(df)} records...")

    # === MERGE PROMOTION DETAILS FIRST (CRITICAL) ===
    if promos is not None:
        promo_cols = ['promo']
        for col in ['promoqty', 'manufacturer', 'promoval']:
            if col in promos.columns and col not in df.columns:
                promo_cols.append(col)

        if len(promo_cols) > 1:
            promos_clean = promos[promo_cols].drop_duplicates('promo')
            df = df.merge(promos_clean, on='promo', how='left')

            # Promotion-level features
            if 'promoval' in df.columns and 'promoqty' in df.columns:
                df['promo_price_per_unit'] = (df['promoval'] / df['promoqty'].replace(0, np.nan)).astype(np.float32)

    # Handle rare categories (vectorized)
    for col, replace_val in [("brand","Other"), ("promo",-1), ("manufacturer","Other")]:
        if col in df.columns:
            rare_vals = train_df[col].value_counts()[lambda x: x < sparse_thresh].index
            df[col] = df[col].replace(rare_vals, replace_val)
            if col in train_df.columns:
                train_df[col] = train_df[col].replace(rare_vals, replace_val)

    # Convert types for memory efficiency
    for col in ["id", "store", "promo"]:
        if col in df.columns:
            df[col] = df[col].astype(np.int32)

    transactions["id"] = transactions["id"].astype(np.int32)
    transactions["store"] = transactions["store"].astype(np.int32)
    transactions["date"] = pd.to_datetime(transactions["date"])
    transactions["qty"] = transactions["qty"].astype(np.float32)
    transactions["amt"] = transactions["amt"].astype(np.float32)

    # Temporal features from promodate (vectorized)
    df["promo_dayofweek"] = df["promodate"].dt.dayofweek.astype(np.int8)
    df["promo_month"] = df["promodate"].dt.month.astype(np.int8)
    df["is_weekend"] = df["promo_dayofweek"].isin([5,6]).astype(np.int8)

    # Target encoding (optimized)
    def fold_safe_te(col):
        if col not in train_df.columns:
            return {}, train_df["active"].mean()
        agg = train_df.groupby(col, observed=True)["active"].agg(["mean","count"])
        global_mean = train_df["active"].mean()
        agg["encoded"] = (agg["mean"]*agg["count"] + global_mean*smooth_k)/(agg["count"] + smooth_k)
        return agg["encoded"].to_dict(), global_mean

    for col, new_col in [("id","item_response_rate"),
                         ("store","store_response_rate"),
                         ("promo","promo_response_rate"),
                         ("category","category_response_rate"),
                         ("brand","brand_response_rate"),
                         ("manufacturer","manufacturer_response_rate")]:
        if col in df.columns:
            te_map, global_mean = fold_safe_te(col)
            df[new_col] = df[col].map(te_map).fillna(global_mean).astype(np.float32)

    # Merge past-only transactions ONCE
    trans_fold = transactions[transactions["id"].isin(df["id"])].copy()
    trans_fold = trans_fold.merge(
        df[["id","store","category","brand","promodate"]].drop_duplicates(),
        on="id", how="inner", suffixes=("", "_promo")
    )
    trans_fold = trans_fold[trans_fold["date"] < trans_fold["promodate"]]

    if len(trans_fold) == 0:
        print("WARNING: No past transactions found! Returning basic features only.")
        # Return df with minimal features to avoid crash
        df["recency"] = 999.0
        df["tx_count"] = 0
        df.drop(columns=['promodate'], inplace=True, errors='ignore')
        return df

    trans_fold["days_diff"] = (trans_fold["promodate"] - trans_fold["date"]).dt.days.astype(np.int16)

    # SINGLE MEGA AGGREGATION for ID level (minimize groupby calls)
    id_agg = trans_fold.groupby("id", observed=True).agg(
        qty_sum=("qty","sum"),
        qty_mean=("qty","mean"),
        amt_sum=("amt","sum"),
        amt_mean=("amt","mean"),
        amt_std=("amt","std"),
        tx_count=("qty","count"),
        last_purchase=("date","max"),
        first_purchase=("date","min"),
        unique_categories=("category","nunique"),
        unique_brands=("brand","nunique"),
        recent_purchase_count=("days_diff", lambda x: (x <= recent_window_days).sum())
    ).reset_index()

    df = df.merge(id_agg, on="id", how="left")

    # Vectorized datetime conversions
    df["recency"] = (df["promodate"] - df["last_purchase"]).dt.days.astype(np.float32)
    df["customer_tenure_days"] = ((df["last_purchase"] - df["first_purchase"]).dt.days).astype(np.float32)

    # Diversity features (vectorized)
    df['category_diversity'] = (df['unique_categories'] / df['tx_count'].replace(0, 1)).astype(np.float32)
    df['brand_diversity'] = (df['unique_brands'] / df['tx_count'].replace(0, 1)).astype(np.float32)

    # Store aggregates (single pass)
    store_agg = trans_fold.groupby("store", observed=True).agg(
        store_qty_mean=("qty","mean"),
        store_amt_mean=("amt","mean"),
        store_tx_count=("qty","count")
    ).reset_index()
    df = df.merge(store_agg, on="store", how="left")

    # Store affinity (optimized)
    id_store_counts = trans_fold.groupby(['id','store'], observed=True).size().reset_index(name='id_store_tx')
    df = df.merge(id_store_counts, on=['id','store'], how='left')
    df['id_store_tx'] = df['id_store_tx'].fillna(0).astype(np.int16)
    df['customer_store_affinity'] = (df['id_store_tx'] / df['tx_count'].replace(0, 1)).astype(np.float32)

    # Brand aggregates (single pass)
    brand_agg = trans_fold.groupby(['id','brand'], observed=True).agg(
        brand_qty_sum=('qty','sum'),
        brand_amt_sum=('amt','sum'),
        brand_tx_count=('qty','count'),
        brand_last_purchase=('date','max')
    ).reset_index()
    df = df.merge(brand_agg, on=['id','brand'], how='left')

    df['brand_last_purchase_recency'] = ((df['promodate'] - df['brand_last_purchase']).dt.days
                                        .fillna(recent_window_days+1).astype(np.float32))
    df['brand_loyalty_score'] = (df['brand_tx_count'].fillna(0) / df['tx_count'].replace(0, 1)).astype(np.float32)

    # Category aggregates (single pass)
    category_agg = trans_fold.groupby(['id','category'], observed=True).agg(
        category_qty_sum=('qty','sum'),
        category_amt_sum=('amt','sum'),
        category_tx_count=('qty','count'),
        category_last_purchase=('date','max')
    ).reset_index()
    df = df.merge(category_agg, on=['id','category'], how='left')

    df['category_last_purchase_recency'] = ((df['promodate'] - df['category_last_purchase']).dt.days
                                            .fillna(recent_window_days+1).astype(np.float32))
    df['purchased_category_before'] = (df['category_tx_count'].fillna(0) > 0).astype(np.int8)

    # Category share
    df['brand_share_in_category'] = (df['brand_tx_count'].fillna(0) /
                                      df['category_tx_count'].fillna(1).replace(0, 1)).astype(np.float32)

    # Manufacturer aggregates (single pass, only if exists)
    if 'manufacturer' in df.columns:
        mfr_agg = trans_fold.groupby(['id','manufacturer'], observed=True).agg(
            mfr_tx_count=('qty','count'),
            mfr_last_purchase=('date','max')
        ).reset_index()
        df = df.merge(mfr_agg, on=['id','manufacturer'], how='left')
        df['mfr_last_purchase_recency'] = ((df['promodate'] - df['mfr_last_purchase']).dt.days
                                           .fillna(recent_window_days+1).astype(np.float32))
        df['mfr_tx_count'] = df['mfr_tx_count'].fillna(0).astype(np.int16)

    # Price sensitivity (vectorized)
    df['avg_amt_per_transaction'] = (df['amt_sum'] / df['tx_count'].replace(0, 1)).astype(np.float32)
    df['amt_coefficient_variation'] = (df['amt_std'] / df['amt_mean'].replace(0, np.nan)).fillna(0).astype(np.float32)

    if 'promoval' in df.columns:
        df['promoval_vs_customer_avg'] = (df['promoval'] / df['avg_amt_per_transaction'].replace(0, 1)).astype(np.float32)
    if 'promoqty' in df.columns:
        df['promoqty_vs_customer_avg_qty'] = (df['promoqty'] / df['qty_mean'].replace(0, 1)).astype(np.float32)

    # Day of week patterns (optimized with observed=True)
    dow_data = trans_fold[['id', 'date']].copy()
    dow_data['dayofweek'] = dow_data['date'].dt.dayofweek
    dow_counts = dow_data.groupby(['id', 'dayofweek'], observed=True).size().unstack(fill_value=0)
    dow_counts.columns = [f'dow_{int(i)}_count' for i in dow_counts.columns]
    df = df.merge(dow_counts.reset_index(), on='id', how='left')
    del dow_data

    for i in range(7):
        col = f'dow_{i}_count'
        if col in df.columns:
            df[col] = df[col].fillna(0).astype(np.int16)

    # Weekend shopper (vectorized)
    if 'dow_5_count' in df.columns and 'dow_6_count' in df.columns:
        df['is_weekend_shopper'] = ((df['dow_5_count'] + df['dow_6_count']) /
                                     df['tx_count'].replace(0, 1) > 0.5).astype(np.int8)

    # Log transforms (vectorized on key features only)
    for col in ["tx_count", "brand_tx_count", "category_tx_count", "recent_purchase_count"]:
        if col in df.columns:
            df[f"log1p_{col}"] = np.log1p(df[col].fillna(0)).astype(np.float32)

    # Ratios (vectorized, most important only)
    df["qty_sum_ratio_store"] = (df["qty_sum"] / df["store_qty_mean"].replace(0, 1)).astype(np.float32)
    df["amt_sum_ratio_store"] = (df["amt_sum"] / df["store_amt_mean"].replace(0, 1)).astype(np.float32)

    # Key interaction features (vectorized)
    df['recency_x_brand_loyalty'] = (df['recency'] * df['brand_loyalty_score']).astype(np.float32)
    df['category_x_brand_response'] = (df['category_response_rate'] * df['brand_response_rate']).astype(np.float32)

    # Competition features (optimized - single window)
    recent_window = trans_fold[trans_fold["days_diff"] <= 30]
    store_cat_comp = recent_window.groupby(["store","category"], observed=True).size().to_dict()
    df["competing_promos_store_30d"] = (
        df.set_index(["store","category"]).index.map(store_cat_comp).fillna(0).astype(np.int16)
    )

    datetime_cols = ['promodate','last_purchase','first_purchase','brand_last_purchase',
                     'category_last_purchase','mfr_last_purchase']
    df.drop(columns=[c for c in datetime_cols if c in df.columns], inplace=True, errors='ignore')

    # Fill any remaining NaN values with 0
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    df[numeric_cols] = df[numeric_cols].fillna(0)

    # Aggressive memory cleanup
    del trans_fold, id_agg, store_agg, brand_agg, category_agg, id_store_counts, recent_window
    if 'mfr_agg' in locals():
        del mfr_agg
    gc.collect()

    print(f"Completed! Generated {len(df.columns)} features.")

    return df

# %% [markdown]
# # Build Model

# %%
from sklearn.model_selection import train_test_split

X_train, X_val = train_test_split(train_history, test_size=0.2, random_state=42, stratify=train_history["active"])

# %%
# Prepare features
import gc
X_train_feat = feature_engineering(X_train, transactions, train_df=X_train, promos=promos)
y_train = X_train["active"]
X_val_feat = feature_engineering(X_val, transactions, train_df=X_train, promos=promos)
y_val = X_val["active"]
X_test = feature_engineering(test_history, transactions, train_df=train_history, promos=promos)

exclude_cols = ["id","promodate","active","last_purchase","first_purchase"]

# # Drop features with feature-importance <= 50
# exclude_cols += [ "dow_6_count", "qty_sum",
#           "amt_sum_ratio_store", "category_response_rate", "category_qty_sum", "mfr_last_purchase_recency",
#           "store_tx_count", "recency_x_brand_loyalty", "brand_share_in_category", "qty_sum_ratio_store",
#           "tx_count", "avg_amt_per_transaction", "mfr_tx_count", "log1p_category_tx_count",
#           "promo_dayofweek", "store", "brand_loyalty_score", "store_amt_mean",
#           "manufacturer", "region", "brand_tx_count", "promoval",
#           "store_qty_mean", "competing_promos_store_30d", "promo", "brand",
#           "brand_qty_sum", "brand_response_rate", "log1p_recent_purchase_count", "category",
#           "log1p_tx_count", "log1p_brand_tx_count","category_x_brand_response", "purchased_category_before",
#           "manufacturer_response_rate", "is_weekend", "is_weekend_shopper", "promoqty",
#           "customer_store_affinity", "promo_month"
#       ]

features = [c for c in X_train_feat.columns if c not in exclude_cols]
# Out:
# Processing 16000 records...
# Completed! Generated 71 features.
# Processing 4000 records...
# Completed! Generated 71 features.
# Processing 10000 records...
# Completed! Generated 71 features.

# %% [markdown]
# ## Model Comparison
#
# We benchmark LightGBM against two simpler models on the same 80/20 validation split. This confirms the algorithm choice is justified — not just a default — and documents how much the added complexity buys us.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import roc_auc_score
import pandas as pd

# Logistic Regression — linear baseline, requires feature scaling
lr = make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000, random_state=42))
lr.fit(X_tr, y_tr)
lr_preds = lr.predict_proba(X_val)[:, 1]
lr_auc   = roc_auc_score(y_val, lr_preds)

# Random Forest — non-linear ensemble, no boosting
rf = RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42, n_jobs=-1)
rf.fit(X_tr, y_tr)
rf_preds = rf.predict_proba(X_val)[:, 1]
rf_auc   = roc_auc_score(y_val, rf_preds)

# LightGBM — already trained above
lgbm_auc = roc_auc_score(y_val, val_preds)

comparison = pd.DataFrame({
    "Model":           ["Logistic Regression", "Random Forest (200 trees)", "LightGBM (gradient boosting)"],
    "Validation AUC":  [round(lr_auc, 4),      round(rf_auc, 4),           round(lgbm_auc, 4)],
    "Notes":           ["Linear baseline",       "Non-linear, no boosting",  "Selected model ✓"]
})

print(comparison.to_string(index=False))
print(f"\nLightGBM lift over Logistic Regression: +{lgbm_auc - lr_auc:+.4f} AUC")
# Out:
#                        Model  Validation AUC                   Notes
#          Logistic Regression          0.7049         Linear baseline
#    Random Forest (200 trees)          0.7075 Non-linear, no boosting
# LightGBM (gradient boosting)          0.7134        Selected model ✓
#
# LightGBM lift over Logistic Regression: ++0.0085 AUC

# %%
# Final Model
from lightgbm import LGBMClassifier, early_stopping, log_evaluation
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(
    X_train_feat[features], y_train,
    test_size=0.2,
    random_state=42,
    stratify=y_train
)

best_params = {
    'feature_fraction': 0.8,
    'lambda_l1': 0.1,
    'lambda_l2': 0.1,
    'learning_rate': 0.02,
    'max_depth': 12,
    'min_child_samples': 20,
    'num_leaves': 40
}

final_model = LGBMClassifier(
    n_estimators=2000,
    objective='binary',
    random_state=42,
    n_jobs=-1,
    **best_params
)

final_model.fit(
    X_tr, y_tr,
    eval_set=[(X_val, y_val)],
    eval_metric='auc',
    callbacks=[early_stopping(stopping_rounds=50),
               log_evaluation(period=50)]
)

train_preds = final_model.predict_proba(
    X_tr, num_iteration=final_model.best_iteration_
)[:,1]

val_preds = final_model.predict_proba(
    X_val, num_iteration=final_model.best_iteration_
)[:,1]

train_auc = roc_auc_score(y_tr, train_preds)
val_auc = roc_auc_score(y_val, val_preds)

print(f"Train AUC: {train_auc:.4f}")
print(f"Validation AUC: {val_auc:.4f}")
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Info] Number of positive: 2592, number of negative: 10208
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009595 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9954
# [LightGBM] [Info] Number of data points in the train set: 12800, number of used features: 66
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202500 -> initscore=-1.370742
# [LightGBM] [Info] Start training from score -1.370742
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.704308	valid_0's binary_logloss: 0.463714
# [100]	valid_0's auc: 0.708366	valid_0's binary_logloss: 0.456065
# [150]	valid_0's auc: 0.713195	valid_0's binary_logloss: 0.452058
# [200]	valid_0's auc: 0.712723	valid_0's binary_logloss: 0.452164
# Early stopping, best iteration is:
# [179]	valid_0's auc: 0.713407	valid_0's binary_logloss: 0.451874
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# Train AUC: 0.8751
# Validation AUC: 0.7134

# %% [markdown]
# ## 5-Fold Cross-Validation
#
# A single 80/20 split gives one AUC number — it may be a lucky or unlucky split. Cross-validation across 5 folds measures mean ± std, confirming the result is stable and not dependent on one particular split.

# %%
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
import numpy as np

# Use the best iteration found during 80/20 training (avoids re-tuning)
best_iter = final_model.best_iteration_

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_aucs = []

X_cv_data = X_train_feat[features]
y_cv_data = y_train

print("5-fold cross-validation (LightGBM, same hyperparameters):\n")
for fold, (tr_idx, val_idx) in enumerate(skf.split(X_cv_data, y_cv_data)):
    X_cv_tr  = X_cv_data.iloc[tr_idx]
    y_cv_tr  = y_cv_data.iloc[tr_idx]
    X_cv_val = X_cv_data.iloc[val_idx]
    y_cv_val = y_cv_data.iloc[val_idx]

    cv_model = LGBMClassifier(
        n_estimators=best_iter,
        objective='binary',
        random_state=42,
        n_jobs=-1,
        **best_params
    )
    cv_model.fit(X_cv_tr, y_cv_tr)
    fold_preds = cv_model.predict_proba(X_cv_val)[:, 1]
    fold_auc   = roc_auc_score(y_cv_val, fold_preds)
    cv_aucs.append(fold_auc)
    print(f"  Fold {fold + 1}:  AUC = {fold_auc:.4f}")

print(f"\n  Cross-validated AUC : {np.mean(cv_aucs):.4f} ± {np.std(cv_aucs):.4f}")
print(f"  Single-split AUC    : {val_auc:.4f}")
diff = abs(val_auc - np.mean(cv_aucs))
print(f"\n  The single-split result is {'within' if diff < 2 * np.std(cv_aucs) else 'outside'} "
      f"2 std of the CV range — the score is {'stable' if diff < 2 * np.std(cv_aucs) else 'unstable'}.")
# Out:
# 5-fold cross-validation (LightGBM, same hyperparameters):
#
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Info] Number of positive: 2592, number of negative: 10208
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009597 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9952
# [LightGBM] [Info] Number of data points in the train set: 12800, number of used features: 66
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202500 -> initscore=-1.370742
# [LightGBM] [Info] Start training from score -1.370742
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
#   Fold 1:  AUC = 0.7046
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Info] Number of positive: 2592, number of negative: 10208
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009209 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9937
# [LightGBM] [Info] Number of data points in the train set: 12800, number of used features: 66
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202500 -> initscore=-1.370742
# [LightGBM] [Info] Start training from score -1.370742
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
#   Fold 2:  AUC = 0.6902
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Info] Number of positive: 2592, number of negative: 10208
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9949
# [LightGBM] [Info] Number of data points in the train set: 12800, number of used features: 66
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202500 -> initscore=-1.370742
# [LightGBM] [Info] Start training from score -1.370742
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
#   Fold 3:  AUC = 0.7021
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Info] Number of positive: 2592, number of negative: 10208
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009657 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9937
# [LightGBM] [Info] Number of data points in the train set: 12800, number of used features: 66
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202500 -> initscore=-1.370742
# [LightGBM] [Info] Start training from score -1.370742
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
#   Fold 4:  AUC = 0.7103
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Info] Number of positive: 2592, number of negative: 10208
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014172 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9952
# [LightGBM] [Info] Number of data points in the train set: 12800, number of used features: 66
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202500 -> initscore=-1.370742
# [LightGBM] [Info] Start training from score -1.370742
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
#   Fold 5:  AUC = 0.7241
#
#   Cross-validated AUC : 0.7063 ± 0.0111
#   Single-split AUC    : 0.7134
#
#   The single-split result is within 2 std of the CV range — the score is stable.

# %% [markdown]
# ## Precision-Recall & Decision Threshold

# %% [markdown]
# Given the 80/20 class imbalance, ROC AUC alone can be misleading. The precision-recall curve shows the tradeoff at every threshold; F1 score identifies the threshold that best balances precision and recall for our imbalanced classes.

# %%
from sklearn.metrics import precision_recall_curve
import numpy as np

precision, recall, thresholds = precision_recall_curve(y_val, val_preds)
f1_scores      = 2 * (precision[:-1] * recall[:-1]) / (precision[:-1] + recall[:-1] + 1e-8)
best_idx       = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1        = f1_scores[best_idx]
baseline       = train_history["active"].mean()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4.5))

ax1.plot(recall, precision, color=C1, lw=2)
ax1.axhline(y=baseline, color=C2, linestyle="--", lw=1.2,
            label=f"Random baseline ({baseline:.2f})")
ax1.scatter(recall[best_idx], precision[best_idx], color=DARK, zorder=5, s=70,
            label=f"Best threshold = {best_threshold:.2f}")
ax1.set_xlabel("Recall  (fraction of responders captured)")
ax1.set_ylabel("Precision  (fraction of flagged who respond)")
ax1.set_title("Precision–Recall Curve")
ax1.set_xlim(0, 1); ax1.set_ylim(0, 1)
ax1.legend()

ax2.plot(thresholds, f1_scores, color=C1, lw=2)
ax2.axvline(x=best_threshold, color=DARK, linestyle="--", lw=1.2,
            label=f"Optimal threshold = {best_threshold:.2f}  (F1 = {best_f1:.3f})")
ax2.set_xlabel("Decision threshold")
ax2.set_ylabel("F1 score")
ax2.set_title("F1 Score vs. Decision Threshold")
ax2.legend()

plt.tight_layout(pad=2)
plt.savefig("precision_recall_curve.png")
plt.show()

y_pred_binary = (val_preds >= best_threshold).astype(int)
n_flagged     = int(y_pred_binary.sum())
n_responders  = int(y_val.sum())
n_captured    = int((y_pred_binary & (y_val == 1)).sum())
print(f"Recommended threshold : {best_threshold:.2f}  (maximises F1 = {best_f1:.3f})")
print(f"Customers flagged     : {n_flagged:,}  ({n_flagged / len(y_val):.1%} of validation set)")
print(f"Responders captured   : {n_captured:,} of {n_responders:,}  ({n_captured / n_responders:.1%} recall)")
print(f"Precision at threshold: {n_captured / n_flagged:.1%}  (vs {baseline:.1%} if targeting randomly)")
# Out:
# Recommended threshold : 0.21  (maximises F1 = 0.430)
# Customers flagged     : 1,199  (37.5% of validation set)
# Responders captured   : 397 of 648  (61.3% recall)
# Precision at threshold: 33.1%  (vs 20.2% if targeting randomly)

# %% [markdown]
# ## Cumulative Gain & Lift

# %%
import numpy as np

sorted_idx       = np.argsort(val_preds)[::-1]
y_sorted         = np.array(y_val)[sorted_idx]
n                = len(y_sorted)
total_responders = y_sorted.sum()
cumulative_resp  = np.cumsum(y_sorted)
population_pct   = np.arange(1, n + 1) / n * 100

gain = cumulative_resp / total_responders * 100
lift = gain / population_pct

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4.5))

ax1.plot(population_pct, gain, color=C1, lw=2, label="Model")
ax1.plot([0, 100], [0, 100], "--", color=C2, lw=1.2, label="Random baseline")
top20_gain = gain[int(n * 0.20) - 1]
ax1.axvline(x=20, color="#AAAAAA", linestyle=":", lw=1)
ax1.axhline(y=top20_gain, color="#AAAAAA", linestyle=":", lw=1)
ax1.scatter([20], [top20_gain], color=DARK, zorder=5, s=60)
ax1.annotate(f"Top 20% → {top20_gain:.0f}%\nof responders captured",
             xy=(20, top20_gain), xytext=(30, top20_gain - 18),
             fontsize=9, color=DARK,
             arrowprops=dict(arrowstyle="->", color=DARK, lw=0.8))
ax1.set_xlabel("% of customers contacted (ranked by score)")
ax1.set_ylabel("% of total responders captured")
ax1.set_title("Cumulative Gain Chart")
ax1.set_xlim(0, 100); ax1.set_ylim(0, 105)
ax1.legend()

ax2.plot(population_pct, lift, color=C1, lw=2)
ax2.axhline(y=1.0, color=C2, linestyle="--", lw=1.2, label="No lift (random)")
top20_lift = lift[int(n * 0.20) - 1]
ax2.axvline(x=20, color="#AAAAAA", linestyle=":", lw=1)
ax2.scatter([20], [top20_lift], color=DARK, zorder=5, s=60)
ax2.annotate(f"Top 20%: {top20_lift:.1f}× lift",
             xy=(20, top20_lift), xytext=(30, top20_lift + 0.1),
             fontsize=9, color=DARK,
             arrowprops=dict(arrowstyle="->", color=DARK, lw=0.8))
ax2.set_xlabel("% of customers contacted (ranked by score)")
ax2.set_ylabel("Lift over random")
ax2.set_title("Lift Chart")
ax2.set_xlim(0, 100)
ax2.legend()

plt.tight_layout(pad=2)
plt.savefig("lift_gain_chart.png")
plt.show()

print("=== Targeting efficiency by score decile ===")
print(f"{'Decile':<10} {'Score threshold':>16} {'Responders captured':>20} {'Lift':>8}")
print("-" * 58)
for decile in [10, 20, 30, 40, 50]:
    idx          = min(int(n * decile / 100) - 1, n - 1)
    threshold    = val_preds[sorted_idx[idx]]
    captured_pct = gain[idx]
    lift_val     = lift[idx]
    print(f"  Top {decile}%  {threshold:>16.3f}  {captured_pct:>18.1f}%  {lift_val:>6.2f}×")
# Out:
# === Targeting efficiency by score decile ===
# Decile      Score threshold  Responders captured     Lift
# ----------------------------------------------------------
#   Top 10%             0.385                25.2%    2.52×
#   Top 20%             0.267                41.0%    2.05×
#   Top 30%             0.231                52.2%    1.74×
#   Top 40%             0.204                62.7%    1.57×
#   Top 50%             0.179                73.9%    1.48×

# %% [markdown]
# ## Calibration Curve

# %%
from sklearn.calibration import calibration_curve

prob_true, prob_pred = calibration_curve(y_val, val_preds, n_bins=10, strategy="uniform")

fig, ax = plt.subplots(figsize=(5.5, 5.5))
ax.plot(prob_pred, prob_true, "o-", color=C1, lw=2, ms=6, label="LightGBM")
ax.plot([0, 1], [0, 1], "--", color=C2, lw=1.2, label="Perfectly calibrated")
ax.fill_between([0, 1], [0, 1], alpha=0.05, color=C2)
ax.set_xlabel("Mean predicted probability")
ax.set_ylabel("Fraction of actual positives")
ax.set_title("Calibration Curve")
ax.set_xlim(0, 1); ax.set_ylim(0, 1)
ax.legend()
plt.tight_layout(pad=1.5)
plt.savefig("calibration_curve.png")
plt.show()

print("Interpretation:")
print("  Points above the diagonal → model underestimates response probability")
print("  Points below the diagonal → model overestimates response probability")
print("  Points near the diagonal  → well-calibrated (probability ≈ observed rate)")
# Out:
# Interpretation:
#   Points above the diagonal → model underestimates response probability
#   Points below the diagonal → model overestimates response probability
#   Points near the diagonal  → well-calibrated (probability ≈ observed rate)

# %%
import pandas as pd
from sklearn.inspection import PartialDependenceDisplay

importance_df = pd.DataFrame({
    "feature"   : features,
    "importance": final_model.feature_importances_
}).sort_values(by="importance", ascending=False).reset_index(drop=True)

top2_features = importance_df.head(2)["feature"].tolist()
X_pdp = X_tr.sample(500, random_state=42)

fig, axes = plt.subplots(1, 2, figsize=(11, 4.5))

PartialDependenceDisplay.from_estimator(
    final_model,
    X_pdp,
    features=top2_features,
    feature_names=list(X_tr.columns),
    ax=axes,
    line_kw={"color": C1, "lw": 2},
    grid_resolution=30,
)

for ax in axes:
    ax.set_title(ax.get_title(), fontsize=12, fontweight="bold", pad=8)

fig.suptitle("Partial Dependence — Top 2 Features by Importance",
             fontsize=13, fontweight="bold", y=1.04)
plt.tight_layout(pad=2)
plt.savefig("partial_dependence.png")
plt.show()

print(f"Features shown: {top2_features}")
print("Y-axis: marginal change in predicted response probability as the feature value varies,")
print("holding all other features at their observed values (averaged over the sample).")
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# Features shown: ['store_response_rate', 'category_amt_sum']
# Y-axis: marginal change in predicted response probability as the feature value varies,
# holding all other features at their observed values (averaged over the sample).

# %% [markdown]
# *(Charts above are saved to disk and downloaded via the cell at the end of this section.)*

# %% [markdown]
# ## 1 · ROC Curve

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_val, val_preds)
roc_auc = auc(fpr, tpr)

fig, ax = plt.subplots(figsize=(5.5, 5))
ax.plot(fpr, tpr, color=C1, lw=2, label=f"LightGBM  (AUC = {roc_auc:.3f})")
ax.plot([0, 1], [0, 1], "--", color=C2, lw=1.2, label="Random baseline")
ax.fill_between(fpr, tpr, alpha=0.07, color=C1)
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.set_title("ROC Curve — Validation Set")
ax.set_xlim(0, 1); ax.set_ylim(0, 1)
ax.legend(loc="lower right")
plt.tight_layout(pad=1.5)
plt.savefig("roc_curve.png")
plt.show()

# %% [markdown]
# ## 2 · Feature Importance Bar Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)

importance_df = pd.DataFrame({
    'feature': features,
    'importance': final_model.feature_importances_
})
importance_df = importance_df.sort_values(by='importance', ascending=False).reset_index(drop=True)

top_n = 20
top = importance_df.head(top_n).iloc[::-1]  # reverse for horizontal bar

fig, ax = plt.subplots(figsize=(7, 6))
ax.barh(top['feature'], top['importance'],
        color='#EF9F27', alpha=0.85, height=0.7)
ax.set_xlabel('Importance score (LightGBM splits)')
ax.set_title(f'Top {top_n} feature importances')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(labelsize=9)
plt.tight_layout()
plt.savefig('feature_importance.png', dpi=150, bbox_inches='tight')
plt.show()
print(importance_df)
# Out:
#                            feature  importance
# 0                      dow_3_count        3176
# 1        amt_coefficient_variation        2877
# 2                      dow_1_count        2820
# 3                      dow_2_count        2817
# 4                      dow_4_count        2804
# 5                      dow_5_count        2785
# 6                      dow_6_count        2725
# 7                      dow_0_count        2715
# 8                  brand_diversity        2645
# 9                          amt_std        2496
# 10                        amt_mean        2432
# 11                        qty_mean        2390
# 12        promoval_vs_customer_avg        2339
# 13              category_diversity        2152
# 14            customer_tenure_days        2071
# 15               unique_categories        1932
# 16                   unique_brands        1885
# 17       mfr_last_purchase_recency        1848
# 18                         amt_sum        1807
# 19  category_last_purchase_recency        1795
# 20           recent_purchase_count        1791
# 21    promoqty_vs_customer_avg_qty        1735
# 22             amt_sum_ratio_store        1697
# 23                category_amt_sum        1591
# 24             store_response_rate        1579
# 25                         recency        1551
# 26             qty_sum_ratio_store        1471
# 27                           store        1373
# 28                         qty_sum        1298
# 29                        tx_count        1191
# 30                  store_amt_mean        1083
# 31                  store_qty_mean        1067
# 32                  store_tx_count        1044
# 33                          region        1025
# 34                 promo_dayofweek         901
# 35     brand_last_purchase_recency         874
# 36      competing_promos_store_30d         860
# 37                    mfr_tx_count         846
# 38                     id_store_tx         655
# 39         recency_x_brand_loyalty         613
# 40             brand_loyalty_score         531
# 41         brand_share_in_category         511
# 42                   brand_amt_sum         488
# 43         avg_amt_per_transaction         469
# 44             promo_response_rate         415
# 45               category_tx_count         403
# 46                category_qty_sum         365
# 47                   brand_qty_sum         321
# 48     log1p_recent_purchase_count         317
# 49                           promo         268
# 50              item_response_rate         250
# 51                  brand_tx_count         212
# 52                  log1p_tx_count          97
# 53              is_weekend_shopper          85
# 54          category_response_rate          82
# 55                    manufacturer          81
# 56         log1p_category_tx_count          80
# 57                        category          65
# 58                           brand          57
# 59            log1p_brand_tx_count          47
# 60                      is_weekend          34
# 61                        promoval          22
# 62             brand_response_rate          15
# 63       purchased_category_before           7
# 64      manufacturer_response_rate           6
# 65       category_x_brand_response           1
# 66                        promoqty           0
# 67         customer_store_affinity           0
# 68                     promo_month           0

# %% [markdown]
# ## 3 · Predicted Probability Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7, 4))
bins = np.linspace(0, 1, 40)

ax.hist(val_preds[y_val == 0], bins=bins, alpha=0.6,
        color='#B4B2A9', label='Did not respond (0)', density=True)
ax.hist(val_preds[y_val == 1], bins=bins, alpha=0.75,
        color='#EF9F27', label='Responded (1)', density=True)

ax.set_xlabel('Predicted probability of response')
ax.set_ylabel('Density')
ax.set_title('Predicted probability distribution by true label')
ax.legend(frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('score_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 4 · SHAP Feature Explanations

# %%
# !pip install shap -q

# %%
import shap
import matplotlib.pyplot as plt

sample = X_val[features].iloc[:300]
explainer = shap.TreeExplainer(final_model)
shap_values = explainer.shap_values(sample)

if isinstance(shap_values, list):
    sv = shap_values[1]
else:
    sv = shap_values

# Summary plot — save before plt.show()
shap.summary_plot(sv, sample, max_display=15, show=False)
plt.tight_layout()
plt.savefig('shap_summary.png', dpi=150, bbox_inches='tight')
plt.show()

# Waterfall plot
top_idx = int(val_preds[:300].argsort()[-1])
base_val = explainer.expected_value
if isinstance(base_val, (list, __import__('numpy').ndarray)):
    base_val = base_val[1]

shap.plots.waterfall(
    shap.Explanation(
        values=sv[top_idx],
        base_values=base_val,
        data=sample.iloc[top_idx],
        feature_names=features
    ),
    show=False
)
plt.tight_layout()
plt.savefig('shap_waterfall.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/shap/explainers/_tree.py:620: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn(

# %% [markdown]
# # Generate Prediction

# %%
import pandas as pd
from lightgbm import LGBMClassifier, early_stopping, log_evaluation

X_train_feat = feature_engineering(train_history, transactions, train_df=train_history, promos=promos)
y_train = train_history["active"]

X_test_feat = feature_engineering(test_history, transactions, train_df=train_history, promos=promos)

final_model = LGBMClassifier(
    n_estimators=2000,
    objective='binary',
    random_state=42,
    n_jobs=-1,
    **best_params
)

final_model.fit(
    X_train_feat[features], y_train,
    eval_set=[(X_train_feat[features], y_train)],
    eval_metric='auc',
    callbacks=[early_stopping(stopping_rounds=50),
               log_evaluation(period=100)]
)

test_preds = final_model.predict_proba(
    X_test_feat[features], num_iteration=final_model.best_iteration_
)[:,1]

predict = pd.DataFrame({
    "id": X_test_feat["id"],
    "active": test_preds
})

predict.to_csv("predict.csv", index=False)

print("Test predictions saved to 'predict.csv'.")
# Out:
# Processing 20000 records...
# Completed! Generated 71 features.
# Processing 10000 records...
# Completed! Generated 71 features.
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Info] Number of positive: 4050, number of negative: 15950
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015169 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10097
# [LightGBM] [Info] Number of data points in the train set: 20000, number of used features: 66
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202500 -> initscore=-1.370742
# [LightGBM] [Info] Start training from score -1.370742
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's auc: 0.79702	valid_0's binary_logloss: 0.424108
# [200]	valid_0's auc: 0.841406	valid_0's binary_logloss: 0.395228
# [300]	valid_0's auc: 0.87996	valid_0's binary_logloss: 0.371911
# [400]	valid_0's auc: 0.907964	valid_0's binary_logloss: 0.351475
# [500]	valid_0's auc: 0.928303	valid_0's binary_logloss: 0.333264
# [600]	valid_0's auc: 0.943807	valid_0's binary_logloss: 0.31654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [700]	valid_0's auc: 0.956228	valid_0's binary_logloss: 0.301198
# [800]	valid_0's auc: 0.96567	valid_0's binary_logloss: 0.287074
# [900]	valid_0's auc: 0.974043	valid_0's binary_logloss: 0.272929
# [1000]	valid_0's auc: 0.980068	valid_0's binary_logloss: 0.260057
# [1100]	valid_0's auc: 0.985108	valid_0's binary_logloss: 0.247588
# [1200]	valid_0's auc: 0.988784	valid_0's binary_logloss: 0.23582
# [1300]	valid_0's auc: 0.991592	valid_0's binary_logloss: 0.224809
# [1400]	valid_0's auc: 0.993894	valid_0's binary_logloss: 0.213907
# [1500]	valid_0's auc: 0.995589	valid_0's binary_logloss: 0.203731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1600]	valid_0's auc: 0.996954	valid_0's binary_logloss: 0.194249
# [1700]	valid_0's auc: 0.997832	valid_0's binary_logloss: 0.185551
# [1800]	valid_0's auc: 0.998553	valid_0's binary_logloss: 0.177012
# [1900]	valid_0's auc: 0.999034	valid_0's binary_logloss: 0.169122
# [2000]	valid_0's auc: 0.99935	valid_0's binary_logloss: 0.161818
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's auc: 0.99935	valid_0's binary_logloss: 0.161818
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# Test predictions saved to 'predict.csv'.

# %% [markdown]
# ## Download Charts

# %%
from google.colab import files

filenames = [
    "class_distribution.png",
    "roc_curve.png",
    "precision_recall_curve.png",
    "lift_gain_chart.png",
    "calibration_curve.png",
    "partial_dependence.png",
    "feature_importance.png",
    "score_distribution.png",
    "shap_summary.png",
    "shap_waterfall.png",
    "predict.csv"
]

for fname in filenames:
    try:
        files.download(fname)
    except Exception as e:
        print(f"Could not download {fname}: {e}")
